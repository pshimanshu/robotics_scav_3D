# %%
import h5py
f = h5py.File('/content/drive/MyDrive/training_prior_outputs_10_48x64_24x54x24_clean_large.h5', 'r')
data = f['tensor']

# %%
print(len(data))
print(len(data[0]))
# Out:
# 14640
# 1

# %%
import matplotlib.pyplot as plt 
sz = len(data)
idx = 8800 #@param {type:'slider', min:0, max:14640, step:200}
x = data[idx][0]
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.voxels(x, facecolors='yellow') 
plt.show()
